# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
boston_df=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv')

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %%
boston_df.head()
df = boston_df

# %% [markdown]
# # Task 1: Become familiar with the dataset

# %% [markdown]
# ## 1. CRIM - Per capita crime rate by town

# %%
# Plot the distribution of CRIM
pyplot.figure(figsize=(10, 6))
sns.histplot(boston_df['CRIM'], bins=30, kde=True)
pyplot.title('Distribution of Per Capita Crime Rate by Town')
pyplot.xlabel('Per Capita Crime Rate (CRIM)')
pyplot.ylabel('Frequency')
pyplot.show()

# %% [markdown]
# ## 2. ZN - Proportion of residential land zoned for lots over 25,000 sq.ft.

# %%
# Plot the distribution of ZN
pyplot.figure(figsize=(10, 6))
sns.histplot(boston_df['ZN'], bins=30, kde=True)
pyplot.title('Distribution of Proportion of Residential Land Zoned for Lots Over 25,000 sq.ft.')
pyplot.xlabel('Proportion of Residential Land Zoned (ZN)')
pyplot.ylabel('Frequency')
pyplot.show()

# %% [markdown]
# ## 3. INDUS - Proportion of non-retail business acres per town

# %%
# Plot the distribution of INDUS
pyplot.figure(figsize=(10, 6))
sns.histplot(boston_df['INDUS'], bins=30, kde=True)
pyplot.title('Distribution of Proportion of Non-Retail Business Acres per Town')
pyplot.xlabel('Proportion of Non-Retail Business Acres (INDUS)')
pyplot.ylabel('Frequency')
pyplot.show()

# %% [markdown]
# ## 4. CHAS - Charles River Dummy Variable

# %%
# Plot the distribution of CHAS
pyplot.figure(figsize=(10, 6))
sns.countplot(x='CHAS', data=boston_df)
pyplot.title('Distribution of Charles River Dummy Variable')
pyplot.xlabel('Charles River Dummy Variable (CHAS)')
pyplot.ylabel('Count')
pyplot.show()

# %% [markdown]
# ## 5. NOX - Nitric Oxides Concentration

# %%
# Plot the distribution of NOX
pyplot.figure(figsize=(10, 6))
sns.histplot(boston_df['NOX'], bins=30, kde=True)
pyplot.title('Distribution of Nitric Oxides Concentration (NOX)')
pyplot.xlabel('Nitric Oxides Concentration (NOX)')
pyplot.ylabel('Frequency')
pyplot.show()

# %% [markdown]
# ## 6. RM - Average Number of Rooms per Dwelling

# %%
# Plot the distribution of RM
pyplot.figure(figsize=(10, 6))
sns.histplot(boston_df['RM'], bins=30, kde=True)
pyplot.title('Distribution of Average Number of Rooms per Dwelling')
pyplot.xlabel('Average Number of Rooms per Dwelling (RM)')
pyplot.ylabel('Frequency')
pyplot.show()

# %% [markdown]
# ## 7. AGE - Proportion of Owner-Occupied Units Built Prior to 1940

# %%
# Plot the distribution of AGE
pyplot.figure(figsize=(10, 6))
sns.histplot(boston_df['AGE'], bins=30, kde=True)
pyplot.title('Distribution of Proportion of Owner-Occupied Units Built Prior to 1940')
pyplot.xlabel('Proportion of Owner-Occupied Units Built Prior to 1940 (AGE)')
pyplot.ylabel('Frequency')
pyplot.show()

# %% [markdown]
# ## 8. DIS - Weighted Distances to Five Boston Employment Centres

# %%
# Plot the distribution of DIS
plt.figure(figsize=(10, 6))
sns.histplot(df['DIS'], bins=30, kde=True)
plt.title('Distribution of Weighted Distances to Five Boston Employment Centres')
plt.xlabel('Weighted Distances to Five Boston Employment Centres (DIS)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 9. RAD - Index of Accessibility to Radial Highways

# %%
# Plot the distribution of RAD
plt.figure(figsize=(10, 6))
sns.histplot(df['RAD'], bins=30, kde=True)
plt.title('Distribution of Index of Accessibility to Radial Highways')
plt.xlabel('Index of Accessibility to Radial Highways (RAD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 10. TAX - Full-Value Property-Tax Rate per $10,000

# %%
# Plot the distribution of TAX
plt.figure(figsize=(10, 6))
sns.histplot(df['TAX'], bins=30, kde=True)
plt.title('Distribution of Full-Value Property-Tax Rate per $10,000')
plt.xlabel('Full-Value Property-Tax Rate per $10,000 (TAX)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 11. PTRATIO - Pupil-Teacher Ratio by Town

# %%
# Plot the distribution of PTRATIO
plt.figure(figsize=(10, 6))
sns.histplot(df['PTRATIO'], bins=30, kde=True)
plt.title('Distribution of Pupil-Teacher Ratio by Town')
plt.xlabel('Pupil-Teacher Ratio (PTRATIO)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 12. LSTAT - % Lower Status of the Population

# %%
# Plot the distribution of LSTAT
plt.figure(figsize=(10, 6))
sns.histplot(df['LSTAT'], bins=30, kde=True)
plt.title('Distribution of % Lower Status of the Population')
plt.xlabel('% Lower Status of the Population (LSTAT)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 13. MEDV - Median Value of Owner-Occupied Homes in $1000's

# %%
# Plot the distribution of MEDV
plt.figure(figsize=(10, 6))
sns.histplot(df['MEDV'], bins=30, kde=True)
plt.title('Distribution of Median Value of Owner-Occupied Homes in $1000\'s')
plt.xlabel('Median Value of Owner-Occupied Homes in $1000\'s (MEDV)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Task 2: Generate Descriptive Statistics and Visualizations

# %% [markdown]
# ## 1. Boxplot for Median Value of Owner-Occupied Homes (MEDV)

# %%
# Boxplot for MEDV
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['MEDV'])
plt.title('Boxplot of Median Value of Owner-Occupied Homes')
plt.xlabel('Median Value of Owner-Occupied Homes in $1000\'s (MEDV)')
plt.show()

# %% [markdown]
# ## 2. Bar Plot for the Charles River Variable (CHAS)

# %%
# Bar plot for CHAS
plt.figure(figsize=(10, 6))
sns.countplot(x='CHAS', data=df)
plt.title('Bar Plot of Charles River Dummy Variable')
plt.xlabel('Charles River Dummy Variable (CHAS)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## 3. Boxplot of MEDV vs AGE (Discretized AGE)

# %%
# Discretize AGE into three groups
bins = [0, 35, 70, df['AGE'].max()]
labels = ['35 years and younger', '35-70 years', '70 years and older']
df['AGE_GROUP'] = pd.cut(df['AGE'], bins=bins, labels=labels)

# Boxplot of MEDV vs AGE_GROUP
plt.figure(figsize=(12, 8))
sns.boxplot(x='AGE_GROUP', y='MEDV', data=df)
plt.title('Boxplot of Median Value of Homes vs Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Median Value of Owner-Occupied Homes in $1000\'s (MEDV)')
plt.show()

# %% [markdown]
# ## 4. Scatter Plot for Nitric Oxide Concentrations (NOX) vs Proportion of Non-Retail Business Acres (INDUS)

# %%
# Scatter plot for NOX vs INDUS
plt.figure(figsize=(10, 6))
sns.scatterplot(x='INDUS', y='NOX', data=df)
plt.title('Scatter Plot of Nitric Oxide Concentrations vs Proportion of Non-Retail Business Acres')
plt.xlabel('Proportion of Non-Retail Business Acres (INDUS)')
plt.ylabel('Nitric Oxides Concentration (NOX)')
plt.show()

# %% [markdown]
# ## 5. Histogram for Pupil-Teacher Ratio (PTRATIO)

# %%
# Histogram for PTRATIO
plt.figure(figsize=(10, 6))
sns.histplot(df['PTRATIO'], bins=30, kde=True)
plt.title('Histogram of Pupil-Teacher Ratio')
plt.xlabel('Pupil-Teacher Ratio (PTRATIO)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Task 3: Use the appropriate tests to answer the questions provided.

# %% [markdown]
# ## 1. Significant Difference in Median Value of Houses Bounded by the Charles River or Not (T-test for Independent Samples)

# %%
from scipy import stats

# Separate the data based on the CHAS variable
bound_river = df[df['CHAS'] == 1]['MEDV']
not_bound_river = df[df['CHAS'] == 0]['MEDV']

# Perform T-test
t_stat, p_value = stats.ttest_ind(bound_river, not_bound_river, equal_var=False)

# Output results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Conclusion
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in median values.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in median values.")
# Out:
# T-statistic: 3.113291312794837
# P-value: 0.0035671700981375174
# Reject the null hypothesis. There is a significant difference in median values.

# %% [markdown]
# ## 2. Difference in Median Values of Houses for Each Proportion of Owner-Occupied Units Built Prior to 1940 (ANOVA)

# %%
# Perform ANOVA
anova_results = stats.f_oneway(
    df[df['AGE_GROUP'] == '35 years and younger']['MEDV'],
    df[df['AGE_GROUP'] == '35-70 years']['MEDV'],
    df[df['AGE_GROUP'] == '70 years and older']['MEDV']
)

# Output results
print(f"F-statistic: {anova_results.statistic}")
print(f"P-value: {anova_results.pvalue}")

# Conclusion
alpha = 0.05
if anova_results.pvalue < alpha:
    print("Reject the null hypothesis. There is a significant difference in median values across age groups.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in median values across age groups.")
# Out:
# F-statistic: 36.40764999196599
# P-value: 1.7105011022702984e-15
# Reject the null hypothesis. There is a significant difference in median values across age groups.

# %% [markdown]
# ## 3. Relationship Between Nitric Oxide Concentrations and Proportion of Non-Retail Business Acres per Town (Pearson Correlation)

# %%
# Calculate Pearson correlation
correlation_coefficient, p_value = stats.pearsonr(df['NOX'], df['INDUS'])

# Output results
print(f"Correlation Coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")

# Conclusion
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant linear relationship.")
else:
    print("Fail to reject the null hypothesis. There is no significant linear relationship.")
# Out:
# Correlation Coefficient: 0.763651446920915
# P-value: 7.913361061241532e-98
# Reject the null hypothesis. There is a significant linear relationship.

# %% [markdown]
# ## 4. Impact of an Additional Weighted Distance on the Median Value of Owner-Occupied Homes (Regression Analysis)

# %%
import statsmodels.api as sm

# Prepare data for regression analysis
X = df[['DIS']]
X = sm.add_constant(X)  # Add constant term for intercept
y = df['MEDV']

# Fit the regression model
model = sm.OLS(y, X).fit()

# Output results
print(model.summary())

# Conclusion
alpha = 0.05
if model.pvalues['DIS'] < alpha:
    print("Reject the null hypothesis. An additional unit increase in distance significantly affects the median value.")
else:
    print("Fail to reject the null hypothesis. An additional unit increase in distance does not significantly affect the median value.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Tue, 06 Aug 2024   Prob (F-statistic):           1.21e-08
# Time:                        22:56:29   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...
